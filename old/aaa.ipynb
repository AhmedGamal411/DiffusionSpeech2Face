# %%
from PIL import Image

image = Image.open('test.png').convert('RGB')

w_s = 128 / (1+2 * 0.5)
h_s = 128 / (1+2 * 0.4)

# %%
image2 = image.crop((0.4*w_s,0.0*h_s,1.6*w_s,1.4*h_s))

# %%
display(image2)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=76x100>
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
