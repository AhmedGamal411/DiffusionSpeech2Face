# %%
# Importing Image class from PIL module
from PIL import Image,ImageFilter
 
# Opens a image in RGB mode
im = Image.open(r"a15.png").convert('RGB')
 
# Blurring the image
#im1 = im.filter(ImageFilter.BoxBlur(14)) # 4 to 14
#im2 = im.filter(ImageFilter.GaussianBlur(5)) # 2 to 6

im = im.resize((128,128))

import random
#im3 = im.filter(ImageFilter.BoxBlur(random.randint(2, 7))).filter(
#           ImageFilter.GaussianBlur(random.randint(1, 3)))

#im3 = im.filter(ImageFilter.BoxBlur(random.randint(1, 5)))

#im3 = im.filter(ImageFilter.GaussianBlur(random.randint(1, 3)))

#im3 = im.filter(ImageFilter.BoxBlur(random.randint(1, 2))).filter(
#           ImageFilter.GaussianBlur(random.randint(1, 1)))


im3 = im
#im1.save("a2.jpeg")
#im2.save("a3.jpeg")
im3.save("a12.png")
im3
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
imgSmall = im3.resize((24,24), resample=Image.Resampling.BILINEAR) # 8 to 24

# Scale back up using NEAREST to original size
result = imgSmall.resize(im3.size, Image.Resampling.NEAREST)
result.save("a10.png")
result
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
im3 = result.filter(ImageFilter.BoxBlur(7)).filter(
           ImageFilter.GaussianBlur(3))
im3.save("a09.png")
im3
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
im3 = im.filter(ImageFilter.BoxBlur(7)).filter(
           ImageFilter.GaussianBlur(4))
im3.save("a08.png")
im3
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
import numpy as np
x = np.array(im3,np.float32)

# %%
x = np.moveaxis(x, -1, 0)

# %%
x.shape
# Out:
# (3, 128, 128)

# %%
x[0].shape
# Out:
# (128, 128)

# %%
n.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/gamal/vsc/DiffusionSpeech2Face/blurranimage.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/blurranimage.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> n.shape
#
# NameError: name 'n' is not defined

# %%
import numpy as np
x = np.array([[[155,  33, 129],
        [161, 218,   6]],

       [[215, 142, 235],
        [143, 249, 164]],

       [[221,  71, 229],
        [ 56,  91, 120]],

       [[236,   4, 177],
        [171, 105,  40]]])

# %%
m = np.hstack((x[0],x[1]))
n = np.hstack((m,x[2]))
n
# Out:
# array([[155,  33, 129, 215, 142, 235, 221,  71, 229],
#        [161, 218,   6, 143, 249, 164,  56,  91, 120]])

# %%
.
# Out:
# array([[155,  33, 129],
#        [161, 218,   6]])

# %%
x
# Out:
# array([[[155,  33, 129],
#         [161, 218,   6]],
#
#        [[215, 142, 235],
#         [143, 249, 164]],
#
#        [[221,  71, 229],
#         [ 56,  91, 120]],
#
#        [[236,   4, 177],
#         [171, 105,  40]]])

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
import numpy as np

model = VGG19(weights='imagenet', include_top=False)

img_path = '/home/gamal/Datasets/Dataset1/Faces/ufuRTqz29no_278.866667_283.900000_face_3.png'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 82ms/step

# %%
features.max()
# Out:
# 154.96358

# %%
features.min()
# Out:
# 0.0

# %%
features.squeeze().shape
# Out:
# (512,)

# %%
random.randint(1, 3)
# Out:
# 1

# %%
features.shape
# Out:
# (1, 7, 7, 512)

# %%
new_arr = features.reshape(-1, features.shape[-1])

# %%
new_arr.shape
# Out:
# (49, 512)

# %%
import numpy as np
z1 = np.zeros((190,128))

# %%
z = np.array( [[1,2,3],[4,5,6],[6,7,8],[9,10,11]])

# %%
z
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [ 6,  7,  8],
#        [ 9, 10, 11]])

# %%
z.shape
# Out:
# (4, 3)

# %%
z.reshape(2,-1).squeeze()
# Out:
# array([[ 1,  2,  3,  4,  5,  6],
#        [ 6,  7,  8,  9, 10, 11]])

# %%
z
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [ 6,  7,  8],
#        [ 9, 10, 11]])

# %%
z[0:2]
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
image = Image.open("12.png").convert('RGB')
im = image.resize((49,49))

im3 = im.filter(ImageFilter.BoxBlur(random.randint(1, 2))).filter(
    ImageFilter.GaussianBlur(random.randint(1, 1)))

pix = np.array(im3,np.float32)
pix = pix / 255
pix = np.moveaxis(pix, -1, 0)
print(pix.shape)

m = np.hstack((pix[0],pix[1]))
n = np.hstack((m,pix[2]))
print(n.shape)

z1 = np.ones((49,768-(3*49)))
print(z1.shape)
image_guide = np.hstack((n,z1))
print(image_guide.shape)

image.close()
im.close()
im3.close()
# Out:
# (3, 49, 49)
# (49, 147)
# (49, 621)
# (49, 768)

# %%
# Importing Image class from PIL module
from PIL import Image,ImageFilter
 
# Opens a image in RGB mode
im = Image.open(r"12.png").convert('RGB')
 
# Blurring the image
#im1 = im.filter(ImageFilter.BoxBlur(14)) # 4 to 14
#im2 = im.filter(ImageFilter.GaussianBlur(5)) # 2 to 6

im = im.resize((128,128))
im = im.crop((1, 1, 127, 127))

import random
#im3 = im.filter(ImageFilter.BoxBlur(random.randint(2, 7))).filter(
#           ImageFilter.GaussianBlur(random.randint(1, 3)))

#im3 = im.filter(ImageFilter.BoxBlur(random.randint(1, 5)))

#im3 = im.filter(ImageFilter.GaussianBlur(random.randint(1, 3)))

im3 = im.filter(ImageFilter.BoxBlur(random.randint(1, 2))).filter(
           ImageFilter.GaussianBlur(random.randint(1, 1)))



#im1.save("a2.jpeg")
#im2.save("a3.jpeg")
im3.save("a12.png")

# %%
import numpy as np
M = 18
N = 18
im=np.array(im3)
tiles = [im[x:x+M,y:y+N] for x in range(0,im.shape[0],M) for y in range(0,im.shape[1],N)]

# %%
pics = np.asarray(tiles)

# %%
pics.shape
# Out:
# (49, 18, 18, 3)

# %%
pics.shape[0]
# Out:
# 49

# %%
pics[0].shape
# Out:
# (18, 18, 3)

# %%
Image.fromarray(pics[0])
# Out:
# <PIL.Image.Image image mode=RGB size=18x18>

# %%
Image.fromarray(pics[1])
# Out:
# <PIL.Image.Image image mode=RGB size=18x18>

# %%
Image.fromarray(pics[2])
# Out:
# <PIL.Image.Image image mode=RGB size=18x18>

# %%
x = Image.fromarray(pics[3])
x.save("a13.png")
x.close()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
  
#img = cv2.imread('a13.png')
img = pics[3]

# Calculate histogram without mask
hist1 = cv2.calcHist([img],[0],None,[256],[0,256])
hist2 = cv2.calcHist([img],[1],None,[256],[0,256])
hist3 = cv2.calcHist([img],[2],None,[256],[0,256])

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(221), plt.imshow(img)
plt.subplot(222), plt.plot(hist1), plt.plot(hist2),plt.plot(hist3)
plt.xlim([0,256])
# Out:
# (0.0, 256.0)

# %%
hist1.shape
# Out:
# (256, 1)

# %%
hist2.shape
# Out:
# (256, 1)

# %%
hist3.shape
# Out:
# (256, 1)

# %%
np.vstack((hist1,hist2)).shape
# Out:
# (512, 1)
