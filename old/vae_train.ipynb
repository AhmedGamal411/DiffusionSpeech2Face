# %%
#https://www.machinelearningnuggets.com/how-to-generate-images-with-variational-autoencoders-vae-and-keras/
from keras.models import Model
from keras import backend as K
from keras import metrics
from keras.losses import mse
import numpy as np
from tensorflow.keras.layers import Input, Dense, Lambda, Conv2D, Flatten, Reshape, Conv2DTranspose,BatchNormalization,LeakyReLU,Dropout
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import configparser
import pathlib
import shutil

# %%
# Loading configurations
configParser = configparser.RawConfigParser()   
configFilePath = r'configuration.txt'
configParser.read(configFilePath)

insert_amd_env_vars =  int(configParser.get('COMMON', 'insert_amd_env_vars'))
HSA_OVERRIDE_GFX_VERSION =  configParser.get('COMMON', 'HSA_OVERRIDE_GFX_VERSION')
ROCM_PATH =  configParser.get('COMMON', 'ROCM_PATH')

if(insert_amd_env_vars != 0):
    os.environ["HSA_OVERRIDE_GFX_VERSION"] = HSA_OVERRIDE_GFX_VERSION
    os.environ["ROCM_PATH"] = ROCM_PATH

# %%
source_dir = configParser.get('extractFaces', 'datasetPathFaces')
base_dir = configParser.get('vae', 'base_dir')
no_images_used = int(configParser.get('vae', 'no_images_used'))
batch_size = 16
img_size = 32

# %%
i = 0
j = 0
user_prev = ""
for root, dirs, files in os.walk(source_dir):

    if(j > no_images_used):
        break

    for file in files:
        #print(file,root)
        i = i + 1
        p_small = pathlib.Path(os.path.dirname(root + "/" + file))
        p_big = p_small.parent.absolute()
        #print(p_small)
        #print(p_big.name)
        user = p_big.name
        folderFace = base_dir + "/" + user
        #print(folderFace)
        #print(absPathFace)
        #Create Directory
        #pathlib.Path(os.path.dirname(absPathGuide)).mkdir(parents=True, exist_ok=True)
        new_file = folderFace + "/" + file
        if(user_prev != user):
            pathlib.Path(os.path.dirname(new_file)).mkdir(parents=True, exist_ok=True)
            shutil.copy2(root + "/" + file, new_file )
            user_prev = user
            #print(user_prev)
            #print(user)
            j = j + 1
            print('image: ' + str(j) + ", " + 'of total images scanned:' + str(i))
# Out:
# image: 1, of total images scanned:1
# image: 2, of total images scanned:493
# image: 3, of total images scanned:1967
# image: 4, of total images scanned:2501
# image: 5, of total images scanned:3135
# image: 6, of total images scanned:3675
# image: 7, of total images scanned:4941
# image: 8, of total images scanned:5069
# image: 9, of total images scanned:6362
# image: 10, of total images scanned:6647
# image: 11, of total images scanned:6848
# image: 12, of total images scanned:6995
# image: 13, of total images scanned:7098
# image: 14, of total images scanned:7629
# image: 15, of total images scanned:9125
# image: 16, of total images scanned:10193
# image: 17, of total images scanned:11336
# image: 18, of total images scanned:11918
# image: 19, of total images scanned:12227
# image: 20, of total images scanned:12575
# image: 21, of total images scanned:13196
# image: 22, of total images scanned:14696
# image: 23, of total images scanned:15099
# image: 24, of total images scanned:15264
# image: 25, of total images scanned:16317
# image: 26, of total images scanned:16937
# image: 27, of total images scanned:17397
# image: 28, of total images scanned:18243
# image: 29, of total images scanned:18375
# image: 30, of total images scanned:18830
# image: 31, of total images scanned:19459
# image: 32, of total images scanned:19660
# image: 33, of total images scanned:19993
# image: 34, of total images scanned:20331
# image: 35, of total images scanned:21471
# image: 36, of total images scanned:22533
# image: 37, of total images scanned:23740
# image: 38, of total images scanned:23968
# image: 39, of total images scanned:24436
# image: 40, of total images scanned:24604
# image: 41, of total images scanned:24685
# image: 42, of total images scanned:25700
# image: 43, of total images scanned:26774
# image: 44, of total images scanned:27668
# image: 45, of total images scanned:28464
# image: 46, of total images scanned:29718
# image: 47, of total images scanned:31216
# image: 48, of total images scanned:32256
# image: 49, of total images scanned:32571
# image: 50, of total images scanned:33190
# image: 51, of total images scanned:33406
# image: 52, of total images scanned:33653
# image: 53, of total images scanned:33890
# image: 54, of total images scanned:34841
# image: 55, of total images scanned:35678
# image: 56, of total images scanned:35840
# image: 57, of total images scanned:36134
# image: 58, of total images scanned:36373
# image: 59, of total images scanned:36496
# image: 60, of total images scanned:37994
# image: 61, of total images scanned:38575
# image: 62, of total images scanned:39102
# image: 63, of total images scanned:39312
# image: 64, of total images scanned:39723
# image: 65, of total images scanned:40017
# image: 66, of total images scanned:40199
# image: 67, of total images scanned:41279
# image: 68, of total images scanned:41372
# image: 69, of total images scanned:41711
# image: 70, of total images scanned:42362
# image: 71, of total images scanned:43427
# image: 72, of total images scanned:43499
# image: 73, of total images scanned:44088
# image: 74, of total images scanned:44184
# image: 75, of total images scanned:44274
# image: 76, of total images scanned:44541
# image: 77, of total images scanned:44814
# image: 78, of total images scanned:44895
# image: 79, of total images scanned:44958
# image: 80, of total images scanned:45042
# image: 81, of total images scanned:45192
# image: 82, of total images scanned:45552
# image: 83, of total images scanned:45654
# image: 84, of total images scanned:46728
# image: 85, of total images scanned:46992
# image: 86, of total images scanned:47236
# image: 87, of total images scanned:47541
# image: 88, of total images scanned:47895
# image: 89, of total images scanned:47958
# image: 90, of total images scanned:48121
# image: 91, of total images scanned:48652
# image: 92, of total images scanned:48835
# image: 93, of total images scanned:49003
# image: 94, of total images scanned:49390
# image: 95, of total images scanned:49555
# image: 96, of total images scanned:50890
# image: 97, of total images scanned:51484
# image: 98, of total images scanned:52171
# image: 99, of total images scanned:52901
# image: 100, of total images scanned:53282
# image: 101, of total images scanned:53611
# image: 102, of total images scanned:54571
# image: 103, of total images scanned:54810
# image: 104, of total images scanned:54861
# image: 105, of total images scanned:55020
# image: 106, of total images scanned:55703
# image: 107, of total images scanned:55918
# image: 108, of total images scanned:56104
# image: 109, of total images scanned:56269
# image: 110, of total images scanned:56899
# image: 111, of total images scanned:57520
# image: 112, of total images scanned:57904
# image: 113, of total images scanned:58459
# image: 114, of total images scanned:58522
# image: 115, of total images scanned:58711
# image: 116, of total images scanned:58944
# image: 117, of total images scanned:59037
# image: 118, of total images scanned:59406
# image: 119, of total images scanned:59523
# image: 120, of total images scanned:60260
# image: 121, of total images scanned:60392
# image: 122, of total images scanned:60458
# image: 123, of total images scanned:60857
# image: 124, of total images scanned:61184
# image: 125, of total images scanned:61271
# image: 126, of total images scanned:61706
# image: 127, of total images scanned:62457
# image: 128, of total images scanned:62874
# image: 129, of total images scanned:63045
# image: 130, of total images scanned:63591
# image: 131, of total images scanned:63723
# image: 132, of total images scanned:64728
# image: 133, of total images scanned:64944
# image: 134, of total images scanned:65154
# image: 135, of total images scanned:66166
# image: 136, of total images scanned:67576
# image: 137, of total images scanned:67877
# image: 138, of total images scanned:68093
# image: 139, of total images scanned:68456
# image: 140, of total images scanned:68776
# image: 141, of total images scanned:69622
# image: 142, of total images scanned:69844
# image: 143, of total images scanned:70450
# image: 144, of total images scanned:71119
# image: 145, of total images scanned:71526
# image: 146, of total images scanned:71961
# image: 147, of total images scanned:72633
# image: 148, of total images scanned:73029
# image: 149, of total images scanned:73218
# image: 150, of total images scanned:73773
# image: 151, of total images scanned:75273
# image: 152, of total images scanned:75438
# image: 153, of total images scanned:76601
# image: 154, of total images scanned:76703
# image: 155, of total images scanned:76987
# image: 156, of total images scanned:77305
# image: 157, of total images scanned:77500
# image: 158, of total images scanned:77719
# image: 159, of total images scanned:77788
# image: 160, of total images scanned:78160
# image: 161, of total images scanned:78518
# image: 162, of total images scanned:78784
# image: 163, of total images scanned:78928
# image: 164, of total images scanned:79156
# image: 165, of total images scanned:79518
# image: 166, of total images scanned:80658
# image: 167, of total images scanned:80952
# image: 168, of total images scanned:81039
# image: 169, of total images scanned:81623
# image: 170, of total images scanned:82637
# image: 171, of total images scanned:82782
# image: 172, of total images scanned:82827
# image: 173, of total images scanned:83858
# image: 174, of total images scanned:84026
# image: 175, of total images scanned:84176
# image: 176, of total images scanned:84332
# image: 177, of total images scanned:84395
# image: 178, of total images scanned:84504
# image: 179, of total images scanned:85293
# image: 180, of total images scanned:86022
# image: 181, of total images scanned:86199
# image: 182, of total images scanned:86470
# image: 183, of total images scanned:86871
# image: 184, of total images scanned:87573
# image: 185, of total images scanned:88089
# image: 186, of total images scanned:88218
# image: 187, of total images scanned:88662
# image: 188, of total images scanned:88770
# image: 189, of total images scanned:88914
# image: 190, of total images scanned:89718
# image: 191, of total images scanned:89805
# image: 192, of total images scanned:90030
# image: 193, of total images scanned:90910
# image: 194, of total images scanned:91521
# image: 195, of total images scanned:92954
# image: 196, of total images scanned:93107
# image: 197, of total images scanned:93188
# image: 198, of total images scanned:94172
# image: 199, of total images scanned:94585
# image: 200, of total images scanned:94745
# image: 201, of total images scanned:94883
# image: 202, of total images scanned:95384
# image: 203, of total images scanned:95570
# image: 204, of total images scanned:95897
# image: 205, of total images scanned:96172
# image: 206, of total images scanned:96310
# image: 207, of total images scanned:96526
# image: 208, of total images scanned:96958
# image: 209, of total images scanned:97885
# image: 210, of total images scanned:98014
# image: 211, of total images scanned:98897
# image: 212, of total images scanned:99248
# image: 213, of total images scanned:99490
# image: 214, of total images scanned:99667
# image: 215, of total images scanned:100039
# image: 216, of total images scanned:100692
# image: 217, of total images scanned:101407
# image: 218, of total images scanned:101581
# image: 219, of total images scanned:101773
# image: 220, of total images scanned:102841
# image: 221, of total images scanned:102946
# image: 222, of total images scanned:103309
# image: 223, of total images scanned:103561
# image: 224, of total images scanned:104170
# image: 225, of total images scanned:104497
# image: 226, of total images scanned:105466
# image: 227, of total images scanned:105828
# image: 228, of total images scanned:107159
# image: 229, of total images scanned:107294
# image: 230, of total images scanned:108393
# image: 231, of total images scanned:109067
# image: 232, of total images scanned:110566
# image: 233, of total images scanned:112066
# image: 234, of total images scanned:112945
# image: 235, of total images scanned:114444
# image: 236, of total images scanned:115038
# image: 237, of total images scanned:115380
# image: 238, of total images scanned:115623
# image: 239, of total images scanned:117123
# image: 240, of total images scanned:117318
# image: 241, of total images scanned:118017
# image: 242, of total images scanned:118937
# image: 243, of total images scanned:120420
# image: 244, of total images scanned:121619
# image: 245, of total images scanned:121640
# image: 246, of total images scanned:121838
# image: 247, of total images scanned:121985
# image: 248, of total images scanned:122396
# image: 249, of total images scanned:123551
# image: 250, of total images scanned:123941
# image: 251, of total images scanned:125411
# image: 252, of total images scanned:126512
# image: 253, of total images scanned:126652
# image: 254, of total images scanned:127423
# image: 255, of total images scanned:127613
# image: 256, of total images scanned:127754
# image: 257, of total images scanned:128324
# image: 258, of total images scanned:128387
# image: 259, of total images scanned:128630
# image: 260, of total images scanned:129304
# image: 261, of total images scanned:130118
# image: 262, of total images scanned:131618
# image: 263, of total images scanned:131990
# image: 264, of total images scanned:133465
# image: 265, of total images scanned:133891
# image: 266, of total images scanned:134050
# image: 267, of total images scanned:134221
# image: 268, of total images scanned:134404
# image: 269, of total images scanned:134584
# image: 270, of total images scanned:136083
# image: 271, of total images scanned:136533
# image: 272, of total images scanned:137313
# image: 273, of total images scanned:137732
# image: 274, of total images scanned:138521
# image: 275, of total images scanned:139131
# image: 276, of total images scanned:139491
# image: 277, of total images scanned:139746
# image: 278, of total images scanned:140318
# image: 279, of total images scanned:140451
# image: 280, of total images scanned:140805
# image: 281, of total images scanned:140918
# image: 282, of total images scanned:141254
# image: 283, of total images scanned:141425
# image: 284, of total images scanned:142514
# image: 285, of total images scanned:142940
# image: 286, of total images scanned:143417
# image: 287, of total images scanned:143664
# image: 288, of total images scanned:144033
# image: 289, of total images scanned:144123
# image: 290, of total images scanned:144567
# image: 291, of total images scanned:145767
# image: 292, of total images scanned:145929
# image: 293, of total images scanned:146675
# image: 294, of total images scanned:146989
# image: 295, of total images scanned:147777
# image: 296, of total images scanned:148746
# image: 297, of total images scanned:149791
# image: 298, of total images scanned:150070
# image: 299, of total images scanned:150166
# image: 300, of total images scanned:150784
# image: 301, of total images scanned:151045
# image: 302, of total images scanned:151411
# image: 303, of total images scanned:151432
# image: 304, of total images scanned:151766
# image: 305, of total images scanned:151995
# image: 306, of total images scanned:152321
# image: 307, of total images scanned:152534
# image: 308, of total images scanned:152795
# image: 309, of total images scanned:152801
# image: 310, of total images scanned:152819
# image: 311, of total images scanned:152969
# image: 312, of total images scanned:153083
# image: 313, of total images scanned:153257
# image: 314, of total images scanned:153326
# image: 315, of total images scanned:153862
# image: 316, of total images scanned:154105
# image: 317, of total images scanned:154543
# image: 318, of total images scanned:154582
# image: 319, of total images scanned:154662
# image: 320, of total images scanned:154767
# image: 321, of total images scanned:154929
# image: 322, of total images scanned:155054
# image: 418, of total images scanned:207050
# image: 419, of total images scanned:207267
# image: 420, of total images scanned:207402
# image: 421, of total images scanned:207852
# image: 422, of total images scanned:208401
# image: 423, of total images scanned:209558
# image: 424, of total images scanned:210527
# image: 425, of total images scanned:211706
# image: 426, of total images scanned:212381
# image: 427, of total images scanned:212612
# image: 428, of total images scanned:213061
# image: 429, of total images scanned:213385
# image: 430, of total images scanned:213484
# image: 431, of total images scanned:213664
# image: 432, of total images scanned:214744
# image: 433, of total images scanned:215812
# image: 434, of total images scanned:216682
# image: 435, of total images scanned:217928
# image: 436, of total images scanned:218180
# image: 437, of total images scanned:218540
# image: 438, of total images scanned:218816
# image: 439, of total images scanned:218990
# image: 440, of total images scanned:219835
# image: 441, of total images scanned:220190
# image: 442, of total images scanned:220325
# image: 443, of total images scanned:220588
# image: 444, of total images scanned:220774
# image: 445, of total images scanned:220896
# image: 446, of total images scanned:221052
# image: 447, of total images scanned:221463
# image: 448, of total images scanned:221691
# image: 449, of total images scanned:222159
# image: 450, of total images scanned:222252
# image: 451, of total images scanned:223161
# image: 452, of total images scanned:223434
# image: 453, of total images scanned:224730
# image: 454, of total images scanned:224916
# image: 455, of total images scanned:225027
# image: 456, of total images scanned:225147
# image: 457, of total images scanned:225306
# image: 458, of total images scanned:225734
# image: 459, of total images scanned:226220
# image: 460, of total images scanned:226457
# image: 461, of total images scanned:226607
# image: 462, of total images scanned:227281
# image: 463, of total images scanned:227933
# image: 464, of total images scanned:229229
# image: 465, of total images scanned:229331
# image: 466, of total images scanned:230273
# image: 467, of total images scanned:230501
# image: 468, of total images scanned:230639
# image: 469, of total images scanned:231071
# image: 470, of total images scanned:231158
# image: 471, of total images scanned:231230
# image: 472, of total images scanned:232053
# image: 473, of total images scanned:232278
# image: 474, of total images scanned:232704
# image: 475, of total images scanned:233060
# image: 476, of total images scanned:233297
# image: 477, of total images scanned:234749
# image: 478, of total images scanned:235769
# image: 479, of total images scanned:237260
# image: 480, of total images scanned:238760
# image: 481, of total images scanned:238922
# image: 482, of total images scanned:239527
# image: 483, of total images scanned:240316
# image: 484, of total images scanned:240670
# image: 485, of total images scanned:240892
# image: 486, of total images scanned:241168
# image: 487, of total images scanned:241381
# image: 488, of total images scanned:242027
# image: 489, of total images scanned:242843
# image: 490, of total images scanned:243795
# image: 491, of total images scanned:244163
# image: 492, of total images scanned:244247
# image: 493, of total images scanned:245745
# image: 494, of total images scanned:245826
# image: 495, of total images scanned:247320
# image: 496, of total images scanned:247795
# image: 497, of total images scanned:248108
# image: 498, of total images scanned:248627
# image: 499, of total images scanned:248915
# image: 500, of total images scanned:249428
# image: 501, of total images scanned:249527
# image: 502, of total images scanned:250178
# image: 503, of total images scanned:250601
# image: 504, of total images scanned:251066
# image: 505, of total images scanned:252559
# image: 506, of total images scanned:253194
# image: 507, of total images scanned:253569
# image: 508, of total images scanned:253750
# image: 509, of total images scanned:253828
# image: 510, of total images scanned:254065
# image: 511, of total images scanned:254992
# image: 512, of total images scanned:255145
# image: 513, of total images scanned:255958
# image: 514, of total images scanned:256423
# image: 515, of total images scanned:256759
# image: 516, of total images scanned:257344
# image: 517, of total images scanned:257554
# image: 518, of total images scanned:258274
# image: 519, of total images scanned:258919
# image: 520, of total images scanned:259258
# image: 521, of total images scanned:259834
# image: 522, of total images scanned:259999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb Cell 4 line <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a> for file in files:
#      <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X26sZmlsZQ%3D%3D?line=9'>10</a>     #print(file,root)
#      <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X26sZmlsZQ%3D%3D?line=10'>11</a>     i = i + 1
# ---> <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X26sZmlsZQ%3D%3D?line=11'>12</a>     p_small = pathlib.Path(os.path.dirname(root + "/" + file))
#      <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X26sZmlsZQ%3D%3D?line=12'>13</a>     p_big = p_small.parent.absolute()
#      <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X26sZmlsZQ%3D%3D?line=13'>14</a>     #print(p_small)
#      <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X26sZmlsZQ%3D%3D?line=14'>15</a>     #print(p_big.name)
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/pathlib.py:1042, in Path.__new__(cls, *args, **kwargs)
#    1040 if cls is Path:
#    1041     cls = WindowsPath if os.name == 'nt' else PosixPath
# -> 1042 self = cls._from_parts(args, init=False)
#    1043 if not self._flavour.is_supported:
#    1044     raise NotImplementedError("cannot instantiate %r on your system"
#    1045                               % (cls.__name__,))
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/pathlib.py:683, in PurePath._from_parts(cls, args, init)
#     678 @classmethod
#     679 def _from_parts(cls, args, init=True):
#     680     # We need to call _parse_args on the instance, so as to get the
#     681     # right flavour.
#     682     self = object.__new__(cls)
# --> 683     drv, root, parts = self._parse_args(args)
#     684     self._drv = drv
#     685     self._root = root
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/pathlib.py:676, in PurePath._parse_args(cls, args)
#     671         else:
#     672             raise TypeError(
#     673                 "argument should be a str object or an os.PathLike "
#     674                 "object returning str, not %r"
#     675                 % type(a))
# --> 676 return cls._flavour.parse_parts(parts)
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/pathlib.py:79, in _Flavour.parse_parts(self, parts)
#      77     for x in reversed(rel.split(sep)):
#      78         if x and x != '.':
# ---> 79             parsed.append(sys.intern(x))
#      80 else:
#      81     if rel and rel != '.':
#
# KeyboardInterrupt:

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
  base_dir,
  label_mode="int",
  validation_split=0.02,
  subset="training",
  seed=100,
  image_size=(img_size, img_size),
  batch_size=batch_size)
  
validation_set = tf.keras.utils.image_dataset_from_directory(
  base_dir,
  validation_split=0.2,
  subset="validation",
  seed=100,
  image_size=(img_size, img_size),
  batch_size=batch_size)
# Out:
# Found 4801 files belonging to 4801 classes.
# Using 4705 files for training.
# Found 4801 files belonging to 4801 classes.
# Using 960 files for validation.

# %%
x_train = np.array([])
for x, y in training_set:
  x_train = np.concatenate([x])
  
x_test = np.array([])
for x, y in validation_set:
  x_test = np.concatenate([x])

# %%
class_names = training_set.class_names
#print(class_names)
plt.figure(figsize=(10, 10))
for images, labels in training_set.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
# Normalize pixel values between 0 and 1
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
# Define input shape and latent dimension
latent_dim = 2
input_shape = (img_size, img_size, 3)
# Encoder network
inputs = Input(shape=input_shape)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
x = Conv2D(8, (3, 3), activation='relu', strides=(2, 2), padding='same')(x)
x = Conv2D(1, (3, 3), activation='relu', padding='same')(x)
shape_before_flattening = K.int_shape(x)
x = Flatten()(x)
z_mean = Dense(latent_dim)(x)
z_log_var = Dense(latent_dim)(x)

# %%
shape_before_flattening
# Out:
# (None, 16, 16, 1)

# %%
# Sampling function
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim))
    return z_mean + K.exp(z_log_var / 2) * epsilon

# Reparameterization trick
z = Lambda(sampling)([z_mean, z_log_var])

# %%
# Decoder network
decoder_input = Input(K.int_shape(z)[1:])
x = Dense(np.prod(shape_before_flattening[1:]), activation='relu')(decoder_input)
x = Reshape(shape_before_flattening[1:])(x)
x = Conv2DTranspose(128, (2, 2), activation='relu', padding='same', )(x)
x = Conv2DTranspose(64, (2, 2), activation='relu', padding='same', strides=(2, 2))(x)
x = Conv2DTranspose(32, (2, 2), activation='relu', padding='same', )(x)
x = Conv2DTranspose(16, (2, 2), activation='relu', padding='same', )(x)
x = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

# %%
num_features = shape_before_flattening[1] * shape_before_flattening[2] * shape_before_flattening[3]

# %%
num_features
# Out:
# 256

# %%
# Define the VAE model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
decoder = Model(decoder_input, x, name='decoder')
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae')

# %%
vae.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_31 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  encoder (Functional)        [(None, 2),               2709
#                               (None, 2),
#                               (None, 2)]
#
#  decoder (Functional)        (None, 32, 32, 3)         44963
#
# =================================================================
# Total params: 47,672
# Trainable params: 47,672
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(vae,"model.png", show_shapes = True,)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

#
5000
# 1/1 [==============================] - 0s 25ms/step - loss: 5115.9106 - kl_loss: 301.9349 - reconstruction_loss: 4.8140 - val_loss: 314308.0312 - val_kl_loss: 342.4786 - val_reconstruction_loss: 313.9656
# Epoch 879/5000
# 1/1 [==============================] - 0s 27ms/step - loss: 5169.4233 - kl_loss: 302.0003 - reconstruction_loss: 4.8674 - val_loss: 310781.5312 - val_kl_loss: 337.9632 - val_reconstruction_loss: 310.4436
# Epoch 880/5000
# 1/1 [==============================] - 0s 21ms/step - loss: 5465.8315 - kl_loss: 298.1055 - reconstruction_loss: 5.1677 - val_loss: 316453.6562 - val_kl_loss: 343.6234 - val_reconstruction_loss: 316.1100
# Epoch 881/5000
# 1/1 [==============================] - 0s 22ms/step - loss: 5629.3379 - kl_loss: 302.9894 - reconstruction_loss: 5.3263 - val_loss: 311208.5625 - val_kl_loss: 337.3111 - val_reconstruction_loss: 310.8712
# Epoch 882/5000
# 1/1 [==============================] - 0s 23ms/step - loss: 5411.9858 - kl_loss: 297.5391 - reconstruction_loss: 5.1144 - val_loss: 314152.4062 - val_kl_loss: 341.1990 - val_reconstruction_loss: 313.8112
# Epoch 883/5000
# 1/1 [==============================] - 0s 23ms/step - loss: 5129.7607 - kl_loss: 300.8887 - reconstruction_loss: 4.8289 - val_loss: 313272.4375 - val_kl_loss: 340.2912 - val_reconstruction_loss: 312.9321
# Epoch 884/5000
# 1/1 [==============================] - 0s 25ms/step - loss: 5041.5708 - kl_loss: 300.1103 - reconstruction_loss: 4.7415 - val_loss: 311747.6250 - val_kl_loss: 338.1070 - val_reconstruction_loss: 311.4095
# Epoch 885/5000
# 1/1 [==============================] - 0s 23ms/step - loss: 5194.7808 - kl_loss: 298.2359 - reconstruction_loss: 4.8965 - val_loss: 316018.0000 - val_kl_loss: 342.5664 - val_reconstruction_loss: 315.6754
# Epoch 886/5000
# 1/1 [==============================] - 0s 24ms/step - loss: 5364.5933 - kl_loss: 302.0957 - reconstruction_loss: 5.0625 - val_loss: 311527.3750 - val_kl_loss: 337.6491 - val_reconstruction_loss: 311.1897
# Epoch 887/5000
# 1/1 [==============================] - ETA: 0s - loss: 5298.0928 - kl_loss: 297.8542 - reconstruction_loss: 5.0002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb Cell 20 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> vae.compile(optimizer='adam')
# ----> <a href='vscode-notebook-cell:/home/gamal/vsc/DiffusionSpeech2Face/vae_train.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> vae.fit(x_train, epochs=5000, batch_size=batch_size, validation_data=(x_test, None))
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/keras/engine/training.py:1694, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1679 if getattr(self, "_eval_data_handler", None) is None:
#    1680     self._eval_data_handler = data_adapter.get_data_handler(
#    1681         x=val_x,
#    1682         y=val_y,
#    (...)
#    1692         steps_per_execution=self._steps_per_execution,
#    1693     )
# -> 1694 val_logs = self.evaluate(
#    1695     x=val_x,
#    1696     y=val_y,
#    1697     sample_weight=val_sample_weight,
#    1698     batch_size=validation_batch_size or batch_size,
#    1699     steps=validation_steps,
#    1700     callbacks=callbacks,
#    1701     max_queue_size=max_queue_size,
#    1702     workers=workers,
#    1703     use_multiprocessing=use_multiprocessing,
#    1704     return_dict=True,
#    1705     _use_cached_eval_dataset=True,
#    1706 )
#    1707 val_logs = {
#    1708     "val_" + name: val for name, val in val_logs.items()
#    1709 }
#    1710 epoch_logs.update(val_logs)
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/keras/engine/training.py:2032, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2030 self._test_counter.assign(0)
#    2031 callbacks.on_test_begin()
# -> 2032 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2033     self.reset_metrics()
#    2034     with data_handler.catch_stop_iteration():
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/keras/engine/data_adapter.py:1304, in DataHandler.enumerate_epochs(self)
#    1302 """Yields `(epoch, tf.data.Iterator)`."""
#    1303 with self._truncate_execution_to_epoch():
# -> 1304     data_iterator = iter(self._dataset)
#    1305     for epoch in range(self._initial_epoch, self._epochs):
#    1306         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:499, in DatasetV2.__iter__(self)
#     497 if context.executing_eagerly() or ops.inside_function():
#     498   with ops.colocate_with(self._variant_tensor):
# --> 499     return iterator_ops.OwnedIterator(self)
#     500 else:
#     501   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     502                      "iteration in eager mode or within tf.function.")
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:703, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     699   if (components is not None or element_spec is not None):
#     700     raise ValueError(
#     701         "When `dataset` is provided, `element_spec` and `components` must "
#     702         "not be specified.")
# --> 703   self._create_iterator(dataset)
#     705 self._get_next_call_count = 0
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:742, in OwnedIterator._create_iterator(self, dataset)
#     739   assert len(fulltype.args[0].args[0].args) == len(
#     740       self._flat_output_types)
#     741   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 742 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/anaconda3/envs/ds2f_pre/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3409, in make_iterator(dataset, iterator, name)
#    3407 if tld.is_eager:
#    3408   try:
# -> 3409     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3410       _ctx, "MakeIterator", name, dataset, iterator)
#    3411     return _result
#    3412   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
# Convert the predictions into images
decoded_imgs = vae.predict(x_test)
# Display the original and reconstructed images
n = 10 # number of images to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display the original image
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(img_size, img_size,3))
    # plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display the reconstructed image
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(img_size, img_size,3))
    # plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 15ms/step
