# %%
#https://towardsdatascience.com/generating-new-faces-with-variational-autoencoders-d13cfcb5f0a8
# %env HSA_OVERRIDE_GFX_VERSION=10.3.0
# %env TF_FORCE_GPU_ALLOW_GROWTH=true
# %env ROCM_PATH=/opt/rocm
import tensorflow as tf
tf.test.is_built_with_rocm()
# document export HSA_OVERRIDE_GFX_VERSION=10.3.0
physical_devices = tf.config.list_physical_devices('GPU')
try:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
  # Invalid device or cannot modify virtual devices once initialized.
  pass

from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()
# Out:
# env: HSA_OVERRIDE_GFX_VERSION=10.3.0
# env: TF_FORCE_GPU_ALLOW_GROWTH=true
# env: ROCM_PATH=/opt/rocm
# 2023-03-19 10:37:27.365028: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-19 10:37:27.439262: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-19 10:37:28.353043: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_SYSTEM_DRIVER_MISMATCH: system has unsupported display driver / cuda driver combination
# 2023-03-19 10:37:28.353062: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: gamal-Alienware-Aurora-R13
# 2023-03-19 10:37:28.353064: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: gamal-Alienware-Aurora-R13
# 2023-03-19 10:37:28.353111: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 510.108.3
# 2023-03-19 10:37:28.353120: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 530.30.2
# 2023-03-19 10:37:28.353122: E tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 530.30.2 does not match DSO version 510.108.3 -- cannot find working devices in this configuration

# %%
import os
from glob import glob

WEIGHTS_FOLDER = './weights/'
DATA_FOLDER = './data/img_align_celeba/'

if not os.path.exists(WEIGHTS_FOLDER):
  os.makedirs(os.path.join(WEIGHTS_FOLDER,"AE"))
  os.makedirs(os.path.join(WEIGHTS_FOLDER,"VAE"))

#Unzip the dataset downloaded from kaggle
from zipfile import ZipFile
with ZipFile('celeba-dataset.zip', 'r') as zipObj:
   # Extract all the contents of zip file in the data directory
   zipObj.extractall('./data/')

# %%
import numpy as np

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint 
from keras.utils import plot_model

# %%
filenames = np.array(glob(os.path.join(DATA_FOLDER, '*/*.jpg')))
NUM_IMAGES = len(filenames)
print("Total number of images : " + str(NUM_IMAGES))
# prints : Total number of images : 202599


INPUT_DIM = (128,128,3) # Image dimension
BATCH_SIZE = 512
Z_DIM = 200 # Dimension of the latent vector (z)

data_flow = ImageDataGenerator(rescale=1./255).flow_from_directory(DATA_FOLDER, 
                                                                   target_size = INPUT_DIM[:2],
                                                                   batch_size = BATCH_SIZE,
                                                                   shuffle = True,
                                                                   class_mode = 'input',
                                                                   subset = 'training'
                                                                   )
# Out:
# Total number of images : 202599
# Found 202599 images belonging to 1 classes.

# %%
# ENCODER
def build_vae_encoder(input_dim, output_dim, conv_filters, conv_kernel_size, 
                  conv_strides, use_batch_norm = False, use_dropout = False):
  
  # Clear tensorflow session to reset layer index numbers to 0 for LeakyRelu, 
  # BatchNormalization and Dropout.
  # Otherwise, the names of above mentioned layers in the model 
  # would be inconsistent
  global K
  K.clear_session()
  
  # Number of Conv layers
  n_layers = len(conv_filters)

  # Define model input
  encoder_input = Input(shape = input_dim, name = 'encoder_input')
  x = encoder_input

  # Add convolutional layers
  for i in range(n_layers):
      x = Conv2D(filters = conv_filters[i], 
                  kernel_size = conv_kernel_size[i],
                  strides = conv_strides[i], 
                  padding = 'same',
                  name = 'encoder_conv_' + str(i)
                  )(x)
      if use_batch_norm:
        x = BathcNormalization()(x)
  
      x = LeakyReLU()(x)

      if use_dropout:
        x = Dropout(rate=0.25)(x)

  # Required for reshaping latent vector while building Decoder
  shape_before_flattening = K.int_shape(x)[1:] 
  
  x = Flatten()(x)
  
  mean_mu = Dense(output_dim, name = 'mu')(x)
  log_var = Dense(output_dim, name = 'log_var')(x)

  # Defining a function for sampling
  def sampling(args):
    mean_mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(mean_mu), mean=0., stddev=1.) 
    return mean_mu + K.exp(log_var/2)*epsilon   
  
  # Using a Keras Lambda Layer to include the sampling function as a layer 
  # in the model
  encoder_output = Lambda(sampling, name='encoder_output')([mean_mu, log_var])

  return encoder_input, encoder_output, mean_mu, log_var, shape_before_flattening, Model(encoder_input, encoder_output)

vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_shape_before_flattening, vae_encoder  = build_vae_encoder(input_dim = INPUT_DIM,
                                    output_dim = Z_DIM, 
                                    conv_filters = [32, 64, 64, 64],
                                    conv_kernel_size = [3,3,3,3],
                                    conv_strides = [2,2,2,2])

# %%
# Decoder
def build_decoder(input_dim, shape_before_flattening, conv_filters, conv_kernel_size, 
                  conv_strides):

  # Number of Conv layers
  n_layers = len(conv_filters)

  # Define model input
  decoder_input = Input(shape = (input_dim,) , name = 'decoder_input')

  # To get an exact mirror image of the encoder
  x = Dense(np.prod(shape_before_flattening))(decoder_input)
  x = Reshape(shape_before_flattening)(x)

  # Add convolutional layers
  for i in range(n_layers):
      x = Conv2DTranspose(filters = conv_filters[i], 
                  kernel_size = conv_kernel_size[i],
                  strides = conv_strides[i], 
                  padding = 'same',
                  name = 'decoder_conv_' + str(i)
                  )(x)
      
      # Adding a sigmoid layer at the end to restrict the outputs 
      # between 0 and 1
      if i < n_layers - 1:
        x = LeakyReLU()(x)
      else:
        x = Activation('sigmoid')(x)

  # Define model output
  decoder_output = x

  return decoder_input, decoder_output, Model(decoder_input, decoder_output)


decoder_input, vae_decoder_output, vae_decoder = build_decoder(input_dim = Z_DIM,
                                        shape_before_flattening = vae_shape_before_flattening,
                                        conv_filters = [64,64,32,3],
                                        conv_kernel_size = [3,3,3,3],
                                        conv_strides = [2,2,2,2]
                                        )

# %%
# The input to the model will be the image fed to the encoder.
vae_input = vae_encoder_input

# Output will be the output of the decoder. The term - decoder(encoder_output) 
# combines the model by passing the encoder output to the input of the decoder.
vae_output = vae_decoder(vae_encoder_output)

# Input to the combined model will be the input to the encoder.
# Output of the combined model will be the output of the decoder.
vae_model = Model(vae_input, vae_output)

# %%
LEARNING_RATE = 0.0005
N_EPOCHS = 40
LOSS_FACTOR = 10000

def r_loss(y_true, y_pred):
    return K.mean(K.square(y_true - y_pred), axis = [1,2,3])

def kl_loss(y_true, y_pred):
    kl_loss =  -0.5 * K.sum(1 + log_var - K.square(mean_mu) - K.exp(log_var), axis = 1)
    return kl_loss

def total_loss(y_true, y_pred):
    return LOSS_FACTOR*r_loss(y_true, y_pred) + kl_loss(y_true, y_pred)
  
adam_optimizer = Adam(lr = LEARNING_RATE)

vae_model.compile(optimizer=adam_optimizer, loss = total_loss, metrics = [r_loss, kl_loss])

checkpoint_vae = ModelCheckpoint(os.path.join(WEIGHTS_FOLDER, 'VAE/weights.h5'), save_weights_only = True, verbose=1)

vae_model.fit_generator(data_flow, 
                        shuffle=True, 
                        epochs = N_EPOCHS, 
                        initial_epoch = 0, 
                        steps_per_epoch=NUM_IMAGES / BATCH_SIZE,
                        callbacks=[checkpoint_vae])
# Out:
# Epoch 1/200
# /home/gamal/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /tmp/ipykernel_3112890/3740166373.py:21: UserWarning: `model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   vae_model.fit_generator(data_flow,
# 2023-03-19 10:38:50.623504: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-19 10:38:50.634519: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2023-03-19 10:38:50.667050: W tensorflow/c/c_api.cc:291] Operation '{name:'decoder_conv_0/kernel/Assign' id:208 op device:{requested: '', assigned: ''} def:{{{node decoder_conv_0/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](decoder_conv_0/kernel, decoder_conv_0/kernel/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-19 10:38:51.066498: W tensorflow/c/c_api.cc:291] Operation '{name:'loss/mul' id:519 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/model_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-19 10:38:51.088859: W tensorflow/c/c_api.cc:291] Operation '{name:'training/Adam/dense/bias/m/Assign' id:886 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense/bias/m, training/Adam/dense/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 398.4204 - r_loss: 0.0353 - kl_loss: 45.6256
# Epoch 1: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 232s 584ms/step - batch: 197.5000 - size: 511.6136 - loss: 398.4205 - r_loss: 0.0353 - kl_loss: 45.6256
# Epoch 2/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 239.3659 - r_loss: 0.0183 - kl_loss: 56.2619
# Epoch 2: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 212s 536ms/step - batch: 197.5000 - size: 511.6136 - loss: 239.3660 - r_loss: 0.0183 - kl_loss: 56.2619
# Epoch 3/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 224.2549 - r_loss: 0.0166 - kl_loss: 58.0260
# Epoch 3: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 194s 491ms/step - batch: 197.5000 - size: 511.6136 - loss: 224.2549 - r_loss: 0.0166 - kl_loss: 58.0260
# Epoch 4/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 217.8171 - r_loss: 0.0159 - kl_loss: 58.9872
# Epoch 4: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 194s 491ms/step - batch: 197.5000 - size: 511.6136 - loss: 217.8171 - r_loss: 0.0159 - kl_loss: 58.9872
# Epoch 5/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 213.9524 - r_loss: 0.0154 - kl_loss: 59.6553
# Epoch 5: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 202s 510ms/step - batch: 197.5000 - size: 511.6136 - loss: 213.9524 - r_loss: 0.0154 - kl_loss: 59.6553
# Epoch 6/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 211.4725 - r_loss: 0.0151 - kl_loss: 60.1331
# Epoch 6: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 198s 501ms/step - batch: 197.5000 - size: 511.6136 - loss: 211.4725 - r_loss: 0.0151 - kl_loss: 60.1331
# Epoch 7/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 209.4329 - r_loss: 0.0149 - kl_loss: 60.3550
# Epoch 7: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 199s 502ms/step - batch: 197.5000 - size: 511.6136 - loss: 209.4329 - r_loss: 0.0149 - kl_loss: 60.3550
# Epoch 8/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 207.9117 - r_loss: 0.0147 - kl_loss: 60.4773
# Epoch 8: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 199s 503ms/step - batch: 197.5000 - size: 511.6136 - loss: 207.9117 - r_loss: 0.0147 - kl_loss: 60.4773
# Epoch 9/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 206.6053 - r_loss: 0.0146 - kl_loss: 60.5758
# Epoch 9: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 203s 513ms/step - batch: 197.5000 - size: 511.6136 - loss: 206.6053 - r_loss: 0.0146 - kl_loss: 60.5758
# Epoch 10/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 205.4641 - r_loss: 0.0145 - kl_loss: 60.6243
# Epoch 10: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 210s 530ms/step - batch: 197.5000 - size: 511.6136 - loss: 205.4641 - r_loss: 0.0145 - kl_loss: 60.6243
# Epoch 11/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 204.5050 - r_loss: 0.0144 - kl_loss: 60.6795
# Epoch 11: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 203s 512ms/step - batch: 197.5000 - size: 511.6136 - loss: 204.5050 - r_loss: 0.0144 - kl_loss: 60.6795
# Epoch 12/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 203.6429 - r_loss: 0.0143 - kl_loss: 60.6828
# Epoch 12: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 207s 524ms/step - batch: 197.5000 - size: 511.6136 - loss: 203.6429 - r_loss: 0.0143 - kl_loss: 60.6828
# Epoch 13/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 202.9227 - r_loss: 0.0142 - kl_loss: 60.7070
# Epoch 13: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 205s 518ms/step - batch: 197.5000 - size: 511.6136 - loss: 202.9227 - r_loss: 0.0142 - kl_loss: 60.7070
# Epoch 14/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 202.2779 - r_loss: 0.0142 - kl_loss: 60.7231
# Epoch 14: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 202s 509ms/step - batch: 197.5000 - size: 511.6136 - loss: 202.2779 - r_loss: 0.0142 - kl_loss: 60.7231
# Epoch 15/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 201.7072 - r_loss: 0.0141 - kl_loss: 60.7500
# Epoch 15: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 204s 515ms/step - batch: 197.5000 - size: 511.6136 - loss: 201.7072 - r_loss: 0.0141 - kl_loss: 60.7500
# Epoch 16/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 201.2139 - r_loss: 0.0140 - kl_loss: 60.7748
# Epoch 16: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 201s 509ms/step - batch: 197.5000 - size: 511.6136 - loss: 201.2139 - r_loss: 0.0140 - kl_loss: 60.7748
# Epoch 17/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 200.6946 - r_loss: 0.0140 - kl_loss: 60.7662
# Epoch 17: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 199s 503ms/step - batch: 197.5000 - size: 511.6136 - loss: 200.6947 - r_loss: 0.0140 - kl_loss: 60.7662
# Epoch 18/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 200.0866 - r_loss: 0.0139 - kl_loss: 60.9118
# Epoch 18: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 505ms/step - batch: 197.5000 - size: 511.6136 - loss: 200.0866 - r_loss: 0.0139 - kl_loss: 60.9118
# Epoch 19/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 199.5172 - r_loss: 0.0138 - kl_loss: 61.0421
# Epoch 19: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 203s 514ms/step - batch: 197.5000 - size: 511.6136 - loss: 199.5172 - r_loss: 0.0138 - kl_loss: 61.0421
# Epoch 20/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 199.0296 - r_loss: 0.0138 - kl_loss: 61.0859
# Epoch 20: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 199s 504ms/step - batch: 197.5000 - size: 511.6136 - loss: 199.0296 - r_loss: 0.0138 - kl_loss: 61.0859
# Epoch 21/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 198.6008 - r_loss: 0.0137 - kl_loss: 61.1257
# Epoch 21: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 199s 503ms/step - batch: 197.5000 - size: 511.6136 - loss: 198.6008 - r_loss: 0.0137 - kl_loss: 61.1257
# Epoch 22/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 198.2029 - r_loss: 0.0137 - kl_loss: 61.1149
# Epoch 22: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 199s 503ms/step - batch: 197.5000 - size: 511.6136 - loss: 198.2029 - r_loss: 0.0137 - kl_loss: 61.1149
# Epoch 23/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 197.9267 - r_loss: 0.0137 - kl_loss: 61.1283
# Epoch 23: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 505ms/step - batch: 197.5000 - size: 511.6136 - loss: 197.9267 - r_loss: 0.0137 - kl_loss: 61.1283
# Epoch 24/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 197.5724 - r_loss: 0.0136 - kl_loss: 61.1364
# Epoch 24: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 201s 507ms/step - batch: 197.5000 - size: 511.6136 - loss: 197.5724 - r_loss: 0.0136 - kl_loss: 61.1364
# Epoch 25/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 197.2710 - r_loss: 0.0136 - kl_loss: 61.1482
# Epoch 25: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 506ms/step - batch: 197.5000 - size: 511.6136 - loss: 197.2709 - r_loss: 0.0136 - kl_loss: 61.1482
# Epoch 26/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 197.0926 - r_loss: 0.0136 - kl_loss: 61.1883
# Epoch 26: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 201s 508ms/step - batch: 197.5000 - size: 511.6136 - loss: 197.0926 - r_loss: 0.0136 - kl_loss: 61.1883
# Epoch 27/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 196.7971 - r_loss: 0.0136 - kl_loss: 61.1832
# Epoch 27: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 198s 502ms/step - batch: 197.5000 - size: 511.6136 - loss: 196.7971 - r_loss: 0.0136 - kl_loss: 61.1832
# Epoch 28/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 196.5812 - r_loss: 0.0135 - kl_loss: 61.1922
# Epoch 28: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 505ms/step - batch: 197.5000 - size: 511.6136 - loss: 196.5812 - r_loss: 0.0135 - kl_loss: 61.1922
# Epoch 29/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 196.4635 - r_loss: 0.0135 - kl_loss: 61.2071
# Epoch 29: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 199s 503ms/step - batch: 197.5000 - size: 511.6136 - loss: 196.4635 - r_loss: 0.0135 - kl_loss: 61.2071
# Epoch 30/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 196.1540 - r_loss: 0.0135 - kl_loss: 61.2104
# Epoch 30: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 201s 508ms/step - batch: 197.5000 - size: 511.6136 - loss: 196.1540 - r_loss: 0.0135 - kl_loss: 61.2104
# Epoch 31/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 196.0052 - r_loss: 0.0135 - kl_loss: 61.2308
# Epoch 31: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 197s 498ms/step - batch: 197.5000 - size: 511.6136 - loss: 196.0052 - r_loss: 0.0135 - kl_loss: 61.2308
# Epoch 32/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 195.8535 - r_loss: 0.0135 - kl_loss: 61.1861
# Epoch 32: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 505ms/step - batch: 197.5000 - size: 511.6136 - loss: 195.8535 - r_loss: 0.0135 - kl_loss: 61.1861
# Epoch 33/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 195.6371 - r_loss: 0.0134 - kl_loss: 61.2123
# Epoch 33: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 505ms/step - batch: 197.5000 - size: 511.6136 - loss: 195.6371 - r_loss: 0.0134 - kl_loss: 61.2123
# Epoch 34/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 195.5828 - r_loss: 0.0134 - kl_loss: 61.2160
# Epoch 34: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 201s 507ms/step - batch: 197.5000 - size: 511.6136 - loss: 195.5828 - r_loss: 0.0134 - kl_loss: 61.2160
# Epoch 35/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 195.4256 - r_loss: 0.0134 - kl_loss: 61.2294
# Epoch 35: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 201s 508ms/step - batch: 197.5000 - size: 511.6136 - loss: 195.4256 - r_loss: 0.0134 - kl_loss: 61.2294
# Epoch 36/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 195.2877 - r_loss: 0.0134 - kl_loss: 61.2612
# Epoch 36: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 505ms/step - batch: 197.5000 - size: 511.6136 - loss: 195.2877 - r_loss: 0.0134 - kl_loss: 61.2612
# Epoch 37/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 195.1600 - r_loss: 0.0134 - kl_loss: 61.2345
# Epoch 37: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 506ms/step - batch: 197.5000 - size: 511.6136 - loss: 195.1600 - r_loss: 0.0134 - kl_loss: 61.2345
# Epoch 38/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 195.0122 - r_loss: 0.0134 - kl_loss: 61.2182
# Epoch 38: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 199s 503ms/step - batch: 197.5000 - size: 511.6136 - loss: 195.0122 - r_loss: 0.0134 - kl_loss: 61.2182
# Epoch 39/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 194.9165 - r_loss: 0.0134 - kl_loss: 61.2305
# Epoch 39: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 202s 510ms/step - batch: 197.5000 - size: 511.6136 - loss: 194.9165 - r_loss: 0.0134 - kl_loss: 61.2305
# Epoch 40/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 194.8218 - r_loss: 0.0134 - kl_loss: 61.2483
# Epoch 40: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 505ms/step - batch: 197.5000 - size: 511.6136 - loss: 194.8218 - r_loss: 0.0134 - kl_loss: 61.2483
# Epoch 41/200
# 396/395 [==============================] - ETA: 0s - batch: 197.5000 - size: 511.6136 - loss: 194.6864 - r_loss: 0.0133 - kl_loss: 61.2274
# Epoch 41: saving model to ./weights/VAE/weights.h5
# 395/395 [==============================] - 200s 507ms/step - batch: 197.5000 - size: 511.6136 - loss: 194.6864 - r_loss: 0.0133 - kl_loss: 61.2274
# Epoch 42/200
#  55/395 [===>..........................] - ETA: 2:54 - batch: 27.0000 - size: 512.0000 - loss: 194.5731 - r_loss: 0.0133 - kl_loss: 61.3604
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 21
#      17 vae_model.compile(optimizer=adam_optimizer, loss = total_loss, metrics = [r_loss, kl_loss])
#      19 checkpoint_vae = ModelCheckpoint(os.path.join(WEIGHTS_FOLDER, 'VAE/weights.h5'), save_weights_only = True, verbose=1)
# ---> 21 vae_model.fit_generator(data_flow,
#      22                         shuffle=True,
#      23                         epochs = N_EPOCHS,
#      24                         initial_epoch = 0,
#      25                         steps_per_epoch=NUM_IMAGES / BATCH_SIZE,
#      26                         callbacks=[checkpoint_vae])
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/engine/training_v1.py:1354, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1342 """Fits the model on data yielded batch-by-batch by a Python generator.
#    1343
#    1344 DEPRECATED:
#    1345   `Model.fit` now supports generators, so there is no longer any need to
#    1346   use this endpoint.
#    1347 """
#    1348 warnings.warn(
#    1349     "`model.fit_generator` is deprecated and "
#    1350     "will be removed in a future version. "
#    1351     "Please use `Model.fit`, which supports generators.",
#    1352     stacklevel=2,
#    1353 )
# -> 1354 return self.fit(
#    1355     generator,
#    1356     steps_per_epoch=steps_per_epoch,
#    1357     epochs=epochs,
#    1358     verbose=verbose,
#    1359     callbacks=callbacks,
#    1360     validation_data=validation_data,
#    1361     validation_steps=validation_steps,
#    1362     validation_freq=validation_freq,
#    1363     class_weight=class_weight,
#    1364     max_queue_size=max_queue_size,
#    1365     workers=workers,
#    1366     use_multiprocessing=use_multiprocessing,
#    1367     shuffle=shuffle,
#    1368     initial_epoch=initial_epoch,
#    1369 )
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/engine/training_v1.py:854, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     851 self._check_call_args("fit")
#     853 func = self._select_training_loop(x)
# --> 854 return func.fit(
#     855     self,
#     856     x=x,
#     857     y=y,
#     858     batch_size=batch_size,
#     859     epochs=epochs,
#     860     verbose=verbose,
#     861     callbacks=callbacks,
#     862     validation_split=validation_split,
#     863     validation_data=validation_data,
#     864     shuffle=shuffle,
#     865     class_weight=class_weight,
#     866     sample_weight=sample_weight,
#     867     initial_epoch=initial_epoch,
#     868     steps_per_epoch=steps_per_epoch,
#     869     validation_steps=validation_steps,
#     870     validation_freq=validation_freq,
#     871     max_queue_size=max_queue_size,
#     872     workers=workers,
#     873     use_multiprocessing=use_multiprocessing,
#     874 )
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/engine/training_generator_v1.py:647, in GeneratorOrSequenceTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing)
#     643 model._validate_or_infer_batch_size(batch_size, steps_per_epoch, x)
#     644 training_utils_v1.check_generator_arguments(
#     645     y, sample_weight, validation_split=validation_split
#     646 )
# --> 647 return fit_generator(
#     648     model,
#     649     x,
#     650     steps_per_epoch=steps_per_epoch,
#     651     epochs=epochs,
#     652     verbose=verbose,
#     653     callbacks=callbacks,
#     654     validation_data=validation_data,
#     655     validation_steps=validation_steps,
#     656     validation_freq=validation_freq,
#     657     class_weight=class_weight,
#     658     max_queue_size=max_queue_size,
#     659     workers=workers,
#     660     use_multiprocessing=use_multiprocessing,
#     661     shuffle=shuffle,
#     662     initial_epoch=initial_epoch,
#     663     steps_name="steps_per_epoch",
#     664 )
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/engine/training_generator_v1.py:282, in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     279 callbacks._call_batch_hook(mode, "begin", step, batch_logs)
#     281 is_deferred = not model._is_compiled
# --> 282 batch_outs = batch_function(*batch_data)
#     283 if not isinstance(batch_outs, list):
#     284     batch_outs = [batch_outs]
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/engine/training_v1.py:1179, in Model.train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1177     self._update_sample_weight_modes(sample_weights=sample_weights)
#    1178     self._make_train_function()
# -> 1179     outputs = self.train_function(ins)
#    1181 if reset_metrics:
#    1182     self.reset_metrics()
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/backend.py:4581, in GraphExecutionFunction.__call__(self, inputs)
#    4571 if (
#    4572     self._callable_fn is None
#    4573     or feed_arrays != self._feed_arrays
#    (...)
#    4577     or session != self._session
#    4578 ):
#    4579     self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 4581 fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    4582 self._call_fetch_callbacks(fetched[-len(self._fetches) :])
#    4583 output_structure = tf.nest.pack_sequence_as(
#    4584     self._outputs_structure,
#    4585     fetched[: len(self.outputs)],
#    4586     expand_composites=True,
#    4587 )
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/tensorflow/python/client/session.py:1481, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1479 try:
#    1480   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1481   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1482                                          self._handle, args,
#    1483                                          run_metadata_ptr)
#    1484   if run_metadata:
#    1485     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

example_batch = next(data_flow)
example_batch = example_batch[0]
example_images = example_batch[:10]

def plot_compare_vae(images=None):
  
  if images is None:
    example_batch = next(data_flow)
    example_batch = example_batch[0]
    images = example_batch[:10]

  n_to_show = images.shape[0]
  reconst_images = vae_model.predict(images)

  fig = plt.figure(figsize=(15, 3))
  fig.subplots_adjust(hspace=0.4, wspace=0.4)

  for i in range(n_to_show):
      img = images[i].squeeze()
      sub = fig.add_subplot(2, n_to_show, i+1)
      sub.axis('off')        
      sub.imshow(img)

  for i in range(n_to_show):
      img = reconst_images[i].squeeze()
      sub = fig.add_subplot(2, n_to_show, i+n_to_show+1)
      sub.axis('off')
      sub.imshow(img)  

plot_compare_vae(images = example_images)

# %%
def vae_generate_images(n_to_show=10):
  reconst_images = vae_decoder.predict(np.random.normal(0,1,size=(n_to_show,Z_DIM)))

  fig = plt.figure(figsize=(15, 3))
  fig.subplots_adjust(hspace=0.4, wspace=0.4)

  for i in range(n_to_show):
        img = reconst_images[i].squeeze()
        sub = fig.add_subplot(2, n_to_show, i+1)
        sub.axis('off')        
        sub.imshow(img)

vae_generate_images(n_to_show=10)
# Out:
# /home/gamal/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-03-19 12:58:54.284580: W tensorflow/c/c_api.cc:291] Operation '{name:'activation/Sigmoid' id:343 op device:{requested: '', assigned: ''} def:{{{node activation/Sigmoid}} = Sigmoid[T=DT_FLOAT, _has_manual_control_dependencies=true](decoder_conv_3/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
vae_model.save('vae_model.h5')
vae_decoder.save('vae_decoder.h5')
vae_encoder.save('vae_encoder.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 vae_model.save('vae_model.h5', compile=False)
#       2 vae_decoder.save('vae_decoder.h5', compile=False)
#       3 vae_encoder.save('vae_encoder.h5', compile=False)
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/envs/ds2f_m_i/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# TypeError: save() got an unexpected keyword argument 'compile'
